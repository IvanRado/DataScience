# %%
import pandas as pd
import matplotlib
from pandas.plotting import scatter_matrix
# %matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')
first_row = recent_grads.iloc[0, :]

first_5 = recent_grads.head()
# print(first_5)

last_5 = recent_grads.tail()
# print(last_5)

recent_grads.describe()

# raw_data_count = 173
# recent_grads = recent_grads.dropna()

# cleaned_data_count, col = recent_grads.shape
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'scatter', title = 'Median vs. Sample Size', figsize = (6,6))

# %%
recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate', kind = 'scatter', title = 'Unemployment Rate vs. Sample Size', figsize = (6,6))

# %%
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'scatter', title = 'Full_time vs. Median', figsize = (6,6))

# %%
recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate', kind = 'scatter', title = 'Share Women vs Unemployment Rate', figsize = (6,6))

# %%
recent_grads.plot(x = 'Men', y = 'Median', kind = 'scatter', title = 'Men vs. Median', figsize = (6,6))

# %%
recent_grads.plot(x = 'Women', y = 'Median', kind = 'scatter', title = 'Women vs. Median', figsize = (6,6))

# %%
recent_grads.plot(x = 'Median', y = 'Women', kind = 'scatter', title = 'Women vs. Median', figsize = (6,6))

# %%
recent_grads['Sample_size'].hist(bins = 50, range = (0,4400))

# %%
recent_grads['Median'].hist(bins = 50, range = (20000,120000))

# %%
recent_grads['Employed'].hist(bins = 45, range = (0,40000))

# %%
recent_grads['Full_time'].hist(bins = 35, range = (0, 25000))

# %%
recent_grads['ShareWomen'].hist(bins = 50, range = (0,1))

# %%
recent_grads['Unemployment_rate'].hist(bins = 25, range = (0, 0.2))

# %%
recent_grads['Men'].hist(bins = 50, range = (0, 200000))

# %%
recent_grads['Women'].hist(bins = 50, range = (0,200000))

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize = (8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C94B09F240>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C94B17E860>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot(x = "Major", y = "ShareWomen", kind = 'bar')

# %%
recent_grads[-10:].plot(x = "Major", y = 'ShareWomen', kind = 'bar')

# %%
recent_grads[:10].plot(x = "Major", y = 'Unemployment_rate', kind = 'bar')

# %%
recent_grads[-10:].plot(x = 'Major', y = 'Unemployment_rate', kind = 'bar')
